# %% [markdown]
# ## ch11. DataFrame for emp

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Data Load
# * df = read_csv()
# * df.info()
# * df.head()
# * df.shape

# %%
df = pd.read_csv("./lec13_emp.csv")

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("./lec13_emp.csv")

# %% [markdown]
# ** <b>info 를 확인해야 하는이유 </b> <br>
# ** objcet 타입이 있어서는 안된다. (글자) <br>
# ** 결측 (NaN) 있어서는 안된다. 널값

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   EMPNO     14 non-null     int64
#  1   ENAME     14 non-null     object
#  2   JOB       14 non-null     object
#  3   MGR       13 non-null     float64
#  4   HIREDATE  14 non-null     object
#  5   SAL       14 non-null     int64
#  6   COMM      4 non-null      float64
#  7   DEPTNO    14 non-null     int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 1.0+ KB

# %%
df.isna() # NaN값 확인
# Out:
#     EMPNO  ENAME    JOB    MGR  HIREDATE    SAL   COMM  DEPTNO
# 0   False  False  False  False     False  False   True   False
# 1   False  False  False  False     False  False  False   False
# 2   False  False  False  False     False  False  False   False
# 3   False  False  False  False     False  False   True   False
# 4   False  False  False  False     False  False  False   False
# 5   False  False  False  False     False  False   True   False
# 6   False  False  False  False     False  False   True   False
# 7   False  False  False  False     False  False   True   False
# 8   False  False  False   True     False  False   True   False
# 9   False  False  False  False     False  False  False   False
# 10  False  False  False  False     False  False   True   False
# 11  False  False  False  False     False  False   True   False
# 12  False  False  False  False     False  False   True   False
# 13  False  False  False  False     False  False   True   False

# %%
df.head()
# Out:
#    EMPNO   ENAME       JOB     MGR    HIREDATE   SAL    COMM  DEPTNO
# 0   7369   SMITH     CLERK  7902.0  1980-12-17   800     NaN      20
# 1   7499   ALLEN  SALESMAN  7698.0  1981-02-20  1600   300.0      30
# 2   7521    WARD  SALESMAN  7698.0  1981-02-22  1250   500.0      30
# 3   7566   JONES   MANAGER  7839.0  1981-04-02  2975     NaN      20
# 4   7654  MARTIN  SALESMAN  7698.0  1981-09-28  1250  1400.0      30

# %%
df.shape
# Out:
# (14, 8)

# %% [markdown]
# * optional

# %%
col_list = df.columns.tolist()
temp = []
for col in col_list:
    col = col.lower()
    temp.append(col)
    
print(temp)
# Out:
# ['empno', 'ename', 'job', 'mgr', 'hiredate', 'sal', 'comm', 'deptno']

# %%
col_list = df.columns.tolist()
temp = []
for i, col in enumerate(col_list):
    col_list[i] = col.lower()
    temp.append(col_list[i])
   
print(temp)
# Out:
# ['empno', 'ename', 'job', 'mgr', 'hiredate', 'sal', 'comm', 'deptno']

# %%
col_list = df.columns.tolist()

for i, col in enumerate(col_list):
    col_list[i] = col.lower()
    
print(col_list)
# Out:
# ['empno', 'ename', 'job', 'mgr', 'hiredate', 'sal', 'comm', 'deptno']

# %%
res1 = [col.lower() for col in col_list]
print(res1)
# Out:
# ['empno', 'ename', 'job', 'mgr', 'hiredate', 'sal', 'comm', 'deptno']

# %%
res = [col_list[i] for i,col in enumerate(col_list)]
print(res)
# Out:
# ['EMPNO', 'ENAME', 'JOB', 'MGR', 'HIREDATE', 'SAL', 'COMM', 'DEPTNO']

# %%
df.columns = res1

# %%
df.head()
# Out:
#    empno   ename       job     mgr    hiredate   sal    comm  deptno
# 0   7369   SMITH     CLERK  7902.0  1980-12-17   800     NaN      20
# 1   7499   ALLEN  SALESMAN  7698.0  1981-02-20  1600   300.0      30
# 2   7521    WARD  SALESMAN  7698.0  1981-02-22  1250   500.0      30
# 3   7566   JONES   MANAGER  7839.0  1981-04-02  2975     NaN      20
# 4   7654  MARTIN  SALESMAN  7698.0  1981-09-28  1250  1400.0      30

# %% [markdown]
# # DataFrame vs SQL

# %%
# select * from emp;
df = pd.read_csv("./lec13_emp.csv")
df[:]
# Out:
#     EMPNO   ENAME        JOB     MGR    HIREDATE   SAL    COMM  DEPTNO
# 0    7369   SMITH      CLERK  7902.0  1980-12-17   800     NaN      20
# 1    7499   ALLEN   SALESMAN  7698.0  1981-02-20  1600   300.0      30
# 2    7521    WARD   SALESMAN  7698.0  1981-02-22  1250   500.0      30
# 3    7566   JONES    MANAGER  7839.0  1981-04-02  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-28  1250  1400.0      30
# 5    7698   BLAKE    MANAGER  7839.0  1981-05-01  2850     NaN      30
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09  2450     NaN      10
# 7    7788   SCOTT    ANALYST  7566.0  1987-07-13  3000     NaN      20
# 8    7839    KING  PRESIDENT     NaN  1981-11-17  5000     NaN      10
# 9    7844  TURNER   SALESMAN  7698.0  1981-09-08  1500     0.0      30
# 10   7876   ADAMS      CLERK  7788.0  1987-07-13  1100     NaN      20
# 11   7900   JAMES      CLERK  7698.0  1981-12-03   950     NaN      30
# ...

# %%
# select empno from emp;
df['empno']
# Out:
# 0     7369
# 1     7499
# 2     7521
# 3     7566
# 4     7654
# 5     7698
# 6     7782
# 7     7788
# 8     7839
# 9     7844
# 10    7876
# 11    7900
# 12    7902
# 13    7934
# Name: empno, dtype: int64

# %%
# select empno, ename, job from emp;
df[['empno','ename','job']]
# Out:
#     empno   ename        job
# 0    7369   SMITH      CLERK
# 1    7499   ALLEN   SALESMAN
# 2    7521    WARD   SALESMAN
# 3    7566   JONES    MANAGER
# 4    7654  MARTIN   SALESMAN
# 5    7698   BLAKE    MANAGER
# 6    7782   CLARK    MANAGER
# 7    7788   SCOTT    ANALYST
# 8    7839    KING  PRESIDENT
# 9    7844  TURNER   SALESMAN
# 10   7876   ADAMS      CLERK
# 11   7900   JAMES      CLERK
# 12   7902    FORD    ANALYST
# 13   7934  MILLER      CLERK

# %%
df.iloc[1:4,0:3]
# Out:
#    empno  ename       job
# 1   7499  ALLEN  SALESMAN
# 2   7521   WARD  SALESMAN
# 3   7566  JONES   MANAGER

# %%
df.loc['1':'3','empno':'job']
# Out:
#    empno  ename       job
# 1   7499  ALLEN  SALESMAN
# 2   7521   WARD  SALESMAN
# 3   7566  JONES   MANAGER

# %% [markdown]
# # df[조건]
#
# # df[컬럼][조건]
# # df[조건][컬럼]

# %%
#select empno, ename, sal from emp where deptno = 10;

df[  ['empno','ename','sal']  ]    [  df['deptno']==10  ]   # [조건]   조건에는 df[조건] 요렇게 데이터프레임을 한번더 씌워야한다.
# Out:
#     empno   ename   sal
# 6    7782   CLARK  2450
# 8    7839    KING  5000
# 13   7934  MILLER  1300

# %%
df[['job','mgr']] [df['deptno'] == 30]
# Out:
#          job     mgr
# 1   SALESMAN  7698.0
# 2   SALESMAN  7698.0
# 4   SALESMAN  7698.0
# 5    MANAGER  7839.0
# 9   SALESMAN  7698.0
# 11     CLERK  7698.0

# %%
df[df['deptno']==10]
# Out:
#     empno   ename        job     mgr    hiredate   sal  comm  deptno
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09  2450   NaN      10
# 8    7839    KING  PRESIDENT     NaN  1981-11-17  5000   NaN      10
# 13   7934  MILLER      CLERK  7782.0  1982-01-23  1300   NaN      10

# %% [markdown]
# ### 멀티조건
# * and &
# * or |
# * 반드시 괄호로 묶어라 [  (df['컬럼'] == 10) & (df['컬럼'] == 'ㅁㅁ')  ]

# %%
# select empno, ename, sal from emp where daptno = 30 and job = 'SALESMAN';      & == and    | == or
df[['empno','ename','sal']] [(df['deptno'] ==30) & (df['job']=='SALESMAN')]
# Out:
#    empno   ename   sal
# 1   7499   ALLEN  1600
# 2   7521    WARD  1250
# 4   7654  MARTIN  1250
# 9   7844  TURNER  1500

# %%
# select job , deptno from emp
# where (deptno = 30 and job = 'SALESMAN') or deptno = 10;

df[['job','deptno']][((df['deptno']==30) & (df['job']=='SALESMAN')) | (df['deptno']==10)]
# Out:
#           job  deptno
# 1    SALESMAN      30
# 2    SALESMAN      30
# 4    SALESMAN      30
# 6     MANAGER      10
# 8   PRESIDENT      10
# 9    SALESMAN      30
# 13      CLERK      10

# %%
# * select ename, job from emp where job = (select job from emp where empno = 7782) ; -->
list = []
for i,n in enumerate(df[['ename','job']]):
    
    df[['ename']][i] = list[i]

print(list)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7520/278879327.py in <module>
#       3 for i,n in enumerate(df[['ename','job']]):
#       4
# ----> 5     df[['ename']][i] = list[i]
#       6
#       7 print(list)
#
# IndexError: list index out of range

# %%
job7782 = df['job'][df['empno']==7782 ].values[0]
print(job7782)
# Out:
# MANAGER

# %%
df[['ename','job']][df['job']==job7782]
# Out:
#    ename      job
# 3  JONES  MANAGER
# 5  BLAKE  MANAGER
# 6  CLARK  MANAGER

# %%
# select ename, job from emp where job in (select job from emp where deptno = 10);
job11 = df['job'][df['deptno']==10 ].values
print(job11)
# Out:
# ['MANAGER' 'PRESIDENT' 'CLERK']

# %%
df[['ename','job']][df['job'].isin(job11)]
# Out:
#      ename        job
# 0    SMITH      CLERK
# 3    JONES    MANAGER
# 5    BLAKE    MANAGER
# 6    CLARK    MANAGER
# 8     KING  PRESIDENT
# 10   ADAMS      CLERK
# 11   JAMES      CLERK
# 13  MILLER      CLERK

# %% [markdown]
# * 컬럼, 컬럼간의 연산

# %% [markdown]
# * 글자(db:vachar2, python:str, df:object) 컬럼, 컬럼간의 연산

# %%
# select ename || job from emp;
# select concat (ename,job) from emp;

# %%
# df['new_col'] = 10

# %%
df['ename']+ df['job']
df['ename_job'] = df['ename']+ '000'+ df['job']
df.head()
# Out:
#    empno   ename       job     mgr    hiredate   sal    comm  deptno  \
# 0   7369   SMITH     CLERK  7902.0  1980-12-17   800     NaN      20
# 1   7499   ALLEN  SALESMAN  7698.0  1981-02-20  1600   300.0      30
# 2   7521    WARD  SALESMAN  7698.0  1981-02-22  1250   500.0      30
# 3   7566   JONES   MANAGER  7839.0  1981-04-02  2975     NaN      20
# 4   7654  MARTIN  SALESMAN  7698.0  1981-09-28  1250  1400.0      30
#
#            ename_job
# 0      SMITH000CLERK
# 1   ALLEN000SALESMAN
# 2    WARD000SALESMAN
# 3    JONES000MANAGER
# 4  MARTIN000SALESMAN

# %% [markdown]
# * 수치 (db:number , python:int float, df:int64 float64)컬럼, 컬럼간의 연산

# %%
# select sal , comm, nvl(comm,0), sal + nvl(comm,0) from emp;

# %%
#df[['sal','comm','sal'+'comm']] # 에러    'sal'+'comm'라는 컬럼은 없다.

# %%
# * NaN 에는 어떤 연산을 가해도 NaN이다
# * db:nvl(clo,0)
# * df.fillna(0)  -----df[컬럼].fillna(0)
# * db: is null ,   * df.isna()   ,df.isnull()
# * db: is not null ,     * df.natna()   , df.notnull()

# %% [markdown]
#  #### 결측 처리 전, 후 비교

# %%
df['comm2'] = df['comm'].fillna(9999)
df.head()   #------------ 원본 comm 이 NaN이 있었기 때문에 데이터 타입은 float(소수점)
# Out:
#    empno   ename       job     mgr    hiredate   sal    comm  deptno   comm2
# 0   7369   SMITH     CLERK  7902.0  1980-12-17   800     NaN      20  9999.0
# 1   7499   ALLEN  SALESMAN  7698.0  1981-02-20  1600   300.0      30   300.0
# 2   7521    WARD  SALESMAN  7698.0  1981-02-22  1250   500.0      30   500.0
# 3   7566   JONES   MANAGER  7839.0  1981-04-02  2975     NaN      20  9999.0
# 4   7654  MARTIN  SALESMAN  7698.0  1981-09-28  1250  1400.0      30  1400.0

# %%
# df['comm2'] = int(df['comm2']) # ---파이썬 문법으론 에러가 난다.

# %%
df['comm2'] = df['comm2'].astype('int64')
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   empno     14 non-null     int64
#  1   ename     14 non-null     object
#  2   job       14 non-null     object
#  3   mgr       13 non-null     float64
#  4   hiredate  14 non-null     object
#  5   sal       14 non-null     int64
#  6   comm      4 non-null      float64
#  7   deptno    14 non-null     int64
#  8   comm2     14 non-null     int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 1.1+ KB

# %%
df['comm'].fillna(0) + df['sal']
# Out:
# 0      800.0
# 1     1900.0
# 2     1750.0
# 3     2975.0
# 4     2650.0
# 5     2850.0
# 6     2450.0
# 7     3000.0
# 8     5000.0
# 9     1500.0
# 10    1100.0
# 11     950.0
# 12    3000.0
# 13    1300.0
# dtype: float64

# %%
df['comm'].isna().sum()
# Out:
# 10

# %%
df.isna().sum()
# Out:
# empno        0
# ename        0
# job          0
# mgr          1
# hiredate     0
# sal          0
# comm        10
# deptno       0
# comm2        0
# dtype: int64

# %%
df['sal+comm2'] = df['sal'] + df['comm2']  # ----> 이거를 한줄로 출력하고싶으면 컬럼에다가 추가를 하고 출력하면 된다.
df[['sal','comm','comm2','sal+comm2']].head()
# Out:
#     sal    comm  comm2  sal+comm2
# 0   800     NaN   9999      10799
# 1  1600   300.0    300       1900
# 2  1250   500.0    500       1750
# 3  2975     NaN   9999      12974
# 4  1250  1400.0   1400       2650

# %% [markdown]
# # Group 함수

# %%
# db : sum()  min() max() avg() count()
# df : value_counts() min() max() sum() mean() ... std() var()

# %%
# select deptno, count(1) from emp group by deptno;


df.groupby(by = 'deptno')['deptno'].value_counts()
# Out:
# deptno  deptno
# 10      10        3
# 20      20        5
# 30      30        6
# Name: deptno, dtype: int64

# %%
# select deptno, avg(sal),min(sal),max(sal),sum(sal) from emp group by deptno;
mydict = {"sal":"max","comm":"min"}    #---- 딕트안에 컬럼이 같으면 표현이 안된다.
#df.groupby(by = 'deptno').agg(mydict)  #여러개 하려면...... 딕셔너리 and 어그리게이션
df.groupby('deptno').agg(mydict)
# Out:
#          sal  comm
# deptno
# 10      5000   NaN
# 20      3000   NaN
# 30      2850   0.0

# %%
# select deptno, avg(sal),min(sal),max(sal),sum(sal) from emp group by deptno;
df.groupby('deptno')['sal'].agg(['min','max','sum','mean'])
# Out:
#          min   max    sum         mean
# deptno
# 10      1300  5000   8750  2916.666667
# 20       800  3000  10875  2175.000000
# 30       950  2850   9400  1566.666667

# %%
# select deptno, avg(sal),min(sal),max(sal),sum(sal) from emp 
# where deptno = 10
# group by deptno;

df[df['deptno']==10].groupby('deptno')['sal'].agg(['min','max','sum','mean'])
# Out:
#          min   max   sum         mean
# deptno
# 10      1300  5000  8750  2916.666667

# %%
df.describe()
# Out:
#              empno          mgr          sal         comm     deptno  \
# count    14.000000    13.000000    14.000000     4.000000  14.000000
# mean   7726.571429  7739.307692  2073.214286   550.000000  22.142857
# std     178.294361   103.714660  1182.503224   602.771377   8.017837
# min    7369.000000  7566.000000   800.000000     0.000000  10.000000
# 25%    7588.000000  7698.000000  1250.000000   225.000000  20.000000
# 50%    7785.000000  7698.000000  1550.000000   400.000000  20.000000
# 75%    7868.000000  7839.000000  2943.750000   725.000000  30.000000
# max    7934.000000  7902.000000  5000.000000  1400.000000  30.000000
#
#              comm2     sal+comm2
# count    14.000000     14.000000
# mean   7299.285714   9372.500000
# std    4439.213399   4998.489753
# min       0.000000   1500.000000
# 25%    3549.750000   4687.250000
# 50%    9999.000000  11199.000000
# 75%    9999.000000  12942.750000
# max    9999.000000  14999.000000

# %%
gdf = df.describe()
gdf["sal"]
gdf.loc[['count','mean','min','max'],['sal','comm']]
# Out:
#                sal    comm
# count    14.000000     4.0
# mean   2073.214286   550.0
# min     800.000000     0.0
# max    5000.000000  1400.0

# %% [markdown]
# * gdf = df.describe()
# * gdf.loc[['count'],['sal','job']]

# %% [markdown]
# # update

# %%
dfcp = df[['empno','ename','sal','job']][df['deptno']==30].copy()

# %%
dfcp.head()
# Out:
#    empno    ename   sal       job
# 1   7499  ALLEN22  1611    CELARK
# 2   7521     WARD  1250  SALESMAN
# 4   7654   MARTIN  1250  SALESMAN
# 5   7698    BLAKE  2850   MANAGER
# 9   7844   TURNER  1500  SALESMAN

# %%
dfcp.iloc[0] = [7499,'ALLEN22','1611','CELARK']

# %%
dfcp
# Out:
#     empno    ename   sal       job
# 1    7499  ALLEN22  1611    CELARK
# 2    7521     WARD  1250  SALESMAN
# 4    7654   MARTIN  1250  SALESMAN
# 5    7698    BLAKE  2850   MANAGER
# 9    7844   TURNER  1500  SALESMAN
# 11   7900    JAMES   950     CLERK

# %% [markdown]
# # delete

# %%
##delete
# df : DDL :drop table, DML : delete record
# df : drop()

# %%
# 행 지우기

# %%
dfcp.drop(index = 11, axis=0)   # 원본상에서는 지워지지 않는다.
# Out:
#    empno    ename   sal       job
# 1   7499  ALLEN22  1611    CELARK
# 2   7521     WARD  1250  SALESMAN
# 4   7654   MARTIN  1250  SALESMAN
# 5   7698    BLAKE  2850   MANAGER
# 9   7844   TURNER  1500  SALESMAN

# %%
dfcp   # 원본상에서는 안지워진 모습
# Out:
#     empno    ename   sal       job
# 1    7499  ALLEN22  1611    CELARK
# 2    7521     WARD  1250  SALESMAN
# 4    7654   MARTIN  1250  SALESMAN
# 5    7698    BLAKE  2850   MANAGER
# 9    7844   TURNER  1500  SALESMAN
# 11   7900    JAMES   950     CLERK

# %%
dfcp.drop(11,axis = 0,inplace=True)  # inpalce=True를 사용해야 실제로 지워진다.

# %%
dfcp = dfcp.drop(9)        #####--------- index = 9 에서 9는 인덱스 값을 의미한다.

# %%
dfcp
# Out:
#    empno    ename   sal       job
# 1   7499  ALLEN22  1611    CELARK
# 2   7521     WARD  1250  SALESMAN
# 4   7654   MARTIN  1250  SALESMAN
# 5   7698    BLAKE  2850   MANAGER

# %%
# 열 ,컬럼 지우기

# %%
# df.drop(['컬럼','컬럼2'],axis = 1) 세로로 지우기 (컬럼 열)
# df.drop([인덱스값,인덱스값],axis = 0) 가로로 지우기 (레코드 행)

# %%
dfcp.drop(['job'], axis=1)
# Out:
#    empno    ename   sal
# 1   7499  ALLEN22  1611
# 2   7521     WARD  1250
# 4   7654   MARTIN  1250
# 5   7698    BLAKE  2850

# %%
dfcp.drop(['job'], axis=1)   #  , inplace =True 를 쓰던가 다시 dfcp에 담는다.

# %%
dfcp = dfcp.drop(['job'], axis=1)

# %%
dfcp
# Out:
#    empno    ename   sal       job
# 1   7499  ALLEN22  1611    CELARK
# 2   7521     WARD  1250  SALESMAN
# 4   7654   MARTIN  1250  SALESMAN
# 5   7698    BLAKE  2850   MANAGER

# %%
dfcp.drop('empno',axis=1)

# %%
dfcp.drop(['ename','sal','empno'],axis=1)

# %% [markdown]
# # Insert

# %% [markdown]
# # join  , merge(union) 중요중요중요

# %% [markdown]
# * CONCAT(db : union,axis=0) : 붙이기 (df(위+아래))
# * MERGE(db : join)   :

# %%
df.head()
#아니면 카피를 해서 업데이트 처럼 써서 df10,df20으로 해줘도 가능하다
# Out:
#    empno   ename       job     mgr    hiredate   sal    comm  deptno  comm2  \
# 0   7369   SMITH     CLERK  7902.0  1980-12-17   800     NaN      20   9999
# 1   7499   ALLEN  SALESMAN  7698.0  1981-02-20  1600   300.0      30    300
# 2   7521    WARD  SALESMAN  7698.0  1981-02-22  1250   500.0      30    500
# 3   7566   JONES   MANAGER  7839.0  1981-04-02  2975     NaN      20   9999
# 4   7654  MARTIN  SALESMAN  7698.0  1981-09-28  1250  1400.0      30   1400
#
#    sal+comm2
# 0      10799
# 1       1900
# 2       1750
# 3      12974
# 4       2650

# %%
dfcp = df.drop(['comm2','sal+comm2'],axis=1)
dfcp
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0    7369   SMITH      CLERK  7902.0  1980-12-17   800     NaN      20
# 1    7499   ALLEN   SALESMAN  7698.0  1981-02-20  1600   300.0      30
# 2    7521    WARD   SALESMAN  7698.0  1981-02-22  1250   500.0      30
# 3    7566   JONES    MANAGER  7839.0  1981-04-02  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-28  1250  1400.0      30
# 5    7698   BLAKE    MANAGER  7839.0  1981-05-01  2850     NaN      30
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09  2450     NaN      10
# 7    7788   SCOTT    ANALYST  7566.0  1987-07-13  3000     NaN      20
# 8    7839    KING  PRESIDENT     NaN  1981-11-17  5000     NaN      10
# 9    7844  TURNER   SALESMAN  7698.0  1981-09-08  1500     0.0      30
# 10   7876   ADAMS      CLERK  7788.0  1987-07-13  1100     NaN      20
# 11   7900   JAMES      CLERK  7698.0  1981-12-03   950     NaN      30
# ...

# %%
df.columns
# Out:
# Index(['empno', 'ename', 'job', 'mgr', 'hiredate', 'sal', 'comm', 'deptno',
#        'comm2', 'sal+comm2'],
#       dtype='object')

# %%
df10 = df[['empno', 'ename', 'job', 'mgr', 'hiredate', 'sal', 'comm', 'deptno']][df['deptno']==10].copy()
df10
# Out:
#     empno   ename        job     mgr    hiredate   sal  comm  deptno
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09  2450   NaN      10
# 8    7839    KING  PRESIDENT     NaN  1981-11-17  5000   NaN      10
# 13   7934  MILLER      CLERK  7782.0  1982-01-23  1300   NaN      10

# %%
df10 = df.drop(['comm2','sal+comm2'],axis=1)[df['deptno'] == 10]
df10
# Out:
#     empno   ename        job     mgr    hiredate   sal  comm  deptno
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09  2450   NaN      10
# 8    7839    KING  PRESIDENT     NaN  1981-11-17  5000   NaN      10
# 13   7934  MILLER      CLERK  7782.0  1982-01-23  1300   NaN      10

# %%
df20 = df.drop(['comm2','sal+comm2'],axis=1)[df['deptno'] == 20]
df20
# Out:
#     empno  ename      job     mgr    hiredate   sal  comm  deptno
# 0    7369  SMITH    CLERK  7902.0  1980-12-17   800   NaN      20
# 3    7566  JONES  MANAGER  7839.0  1981-04-02  2975   NaN      20
# 7    7788  SCOTT  ANALYST  7566.0  1987-07-13  3000   NaN      20
# 10   7876  ADAMS    CLERK  7788.0  1987-07-13  1100   NaN      20
# 12   7902   FORD  ANALYST  7566.0  1981-12-03  3000   NaN      20

# %%
#합쳐보자

# %%
# concat axis =1 로했다 == 좌+우 합친다 ==아우터 조인

# %%
df10201 = pd.concat([df10,df20], axis=1)    # 좌 + 우 합치기
df10201
# Out:
#      empno   ename        job     mgr    hiredate     sal  comm  deptno  \
# 0      NaN     NaN        NaN     NaN         NaN     NaN   NaN     NaN
# 3      NaN     NaN        NaN     NaN         NaN     NaN   NaN     NaN
# 6   7782.0   CLARK    MANAGER  7839.0  1981-06-09  2450.0   NaN    10.0
# 7      NaN     NaN        NaN     NaN         NaN     NaN   NaN     NaN
# 8   7839.0    KING  PRESIDENT     NaN  1981-11-17  5000.0   NaN    10.0
# 10     NaN     NaN        NaN     NaN         NaN     NaN   NaN     NaN
# 12     NaN     NaN        NaN     NaN         NaN     NaN   NaN     NaN
# 13  7934.0  MILLER      CLERK  7782.0  1982-01-23  1300.0   NaN    10.0
#
#      empno  ename      job     mgr    hiredate     sal  comm  deptno
# 0   7369.0  SMITH    CLERK  7902.0  1980-12-17   800.0   NaN    20.0
# 3   7566.0  JONES  MANAGER  7839.0  1981-04-02  2975.0   NaN    20.0
# 6      NaN    NaN      NaN     NaN         NaN     NaN   NaN     NaN
# ...

# %%
df10200 = pd.concat([df10 , df20], axis=0)   #컨캣   축 axis 기본값 0 으로 설정되어있다.
df10200
# Out:
#     empno   ename        job     mgr    hiredate   sal  comm  deptno
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09  2450   NaN      10
# 8    7839    KING  PRESIDENT     NaN  1981-11-17  5000   NaN      10
# 13   7934  MILLER      CLERK  7782.0  1982-01-23  1300   NaN      10
# 0    7369   SMITH      CLERK  7902.0  1980-12-17   800   NaN      20
# 3    7566   JONES    MANAGER  7839.0  1981-04-02  2975   NaN      20
# 7    7788   SCOTT    ANALYST  7566.0  1987-07-13  3000   NaN      20
# 10   7876   ADAMS      CLERK  7788.0  1987-07-13  1100   NaN      20
# 12   7902    FORD    ANALYST  7566.0  1981-12-03  3000   NaN      20

# %%
df10200 = pd.concat([df10 , df20], axis=0, ignore_index=True)   #ignore_index=True로 위아래 합친다음 인덱스 재정렬하기
df10200
# Out:
#    empno   ename        job     mgr    hiredate   sal  comm  deptno
# 0   7782   CLARK    MANAGER  7839.0  1981-06-09  2450   NaN      10
# 1   7839    KING  PRESIDENT     NaN  1981-11-17  5000   NaN      10
# 2   7934  MILLER      CLERK  7782.0  1982-01-23  1300   NaN      10
# 3   7369   SMITH      CLERK  7902.0  1980-12-17   800   NaN      20
# 4   7566   JONES    MANAGER  7839.0  1981-04-02  2975   NaN      20
# 5   7788   SCOTT    ANALYST  7566.0  1987-07-13  3000   NaN      20
# 6   7876   ADAMS      CLERK  7788.0  1987-07-13  1100   NaN      20
# 7   7902    FORD    ANALYST  7566.0  1981-12-03  3000   NaN      20

# %%
dfcp
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0    7369   SMITH      CLERK  7902.0  1980-12-17   800     NaN      20
# 1    7499   ALLEN   SALESMAN  7698.0  1981-02-20  1600   300.0      30
# 2    7521    WARD   SALESMAN  7698.0  1981-02-22  1250   500.0      30
# 3    7566   JONES    MANAGER  7839.0  1981-04-02  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-28  1250  1400.0      30
# 5    7698   BLAKE    MANAGER  7839.0  1981-05-01  2850     NaN      30
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09  2450     NaN      10
# 7    7788   SCOTT    ANALYST  7566.0  1987-07-13  3000     NaN      20
# 8    7839    KING  PRESIDENT     NaN  1981-11-17  5000     NaN      10
# 9    7844  TURNER   SALESMAN  7698.0  1981-09-08  1500     0.0      30
# 10   7876   ADAMS      CLERK  7788.0  1987-07-13  1100     NaN      20
# 11   7900   JAMES      CLERK  7698.0  1981-12-03   950     NaN      30
# ...

# %%
# join == inner

# %%
df1020_1 = pd.concat([dfcp,df10], axis=1, join='inner')
df1020_1
# Out:
#     empno   ename        job     mgr    hiredate   sal  comm  deptno  empno  \
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09  2450   NaN      10   7782
# 8    7839    KING  PRESIDENT     NaN  1981-11-17  5000   NaN      10   7839
# 13   7934  MILLER      CLERK  7782.0  1982-01-23  1300   NaN      10   7934
#
#      ename        job     mgr    hiredate   sal  comm  deptno
# 6    CLARK    MANAGER  7839.0  1981-06-09  2450   NaN      10
# 8     KING  PRESIDENT     NaN  1981-11-17  5000   NaN      10
# 13  MILLER      CLERK  7782.0  1982-01-23  1300   NaN      10

# %%
# Series 합치기
# pd.Series
# pd.DataFrame

# %%
s1 = pd.Series(data=[1,2,3,4,5])  # 파라미터 속성 : data index name
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s1 = pd.Series(data=[1,2,3,4,5], index=[10,20,30,40,50])  # 파라미터 속성 : data index name
s1
# Out:
# 10    1
# 20    2
# 30    3
# 40    4
# 50    5
# dtype: int64

# %%
s1 = pd.Series(data=[1,2,3,4,5], index=[10,20,30,40,50],name="s1name")  # 파라미터 속성 : data index name
s1
# Out:
# 10    1
# 20    2
# 30    3
# 40    4
# 50    5
# Name: s1name, dtype: int64

# %%
s1 = pd.Series(data=[1,2,3,4,5])  # 파라미터 속성 : data index name
s2 = pd.Series(data=[10,20,30,40,50])
print(s1,s2)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s12 = pd.concat([s1,s2],axis=1)
print(s12,type(s12))
# Out:
#    0   1
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
# 4  5  50 <class 'pandas.core.frame.DataFrame'>

# %%
s12.columns = ['col1','col2']
s12
# Out:
#    col1  col2
# 0     1    10
# 1     2    20
# 2     3    30
# 3     4    40
# 4     5    50

# %%
s1 = pd.Series(data=[1,2,3,4,5],name="col1")
s2 = pd.Series(data=[10,20,30,40,50],name="col2") #시리즈의 네임값은 컬럼으로 관리가 되어진다
s12= pd.concat([s1,s2],axis=1)
s12
# Out:
#    col1  col2
# 0     1    10
# 1     2    20
# 2     3    30
# 3     4    40
# 4     5    50

# %%
# df + series 합치기

# %%
df10
# Out:
#     empno   ename        job     mgr    hiredate   sal  comm  deptno
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09  2450   NaN      10
# 8    7839    KING  PRESIDENT     NaN  1981-11-17  5000   NaN      10
# 13   7934  MILLER      CLERK  7782.0  1982-01-23  1300   NaN      10

# %%
df10 = df10 + list_data
df10  #값이 안에 들어가버린다.
# Out:
#     empno        ename             job      mgr              hiredate   sal  \
# 6   15716   CLARKMIL99    MANAGERCLERK  15621.0  1981-06-091982-01-23  3750
# 8   15773    KINGMIL99  PRESIDENTCLERK      NaN  1981-11-171982-01-23  6300
# 13  15868  MILLERMIL99      CLERKCLERK  15564.0  1982-01-231982-01-23  2600
#
#    comm deptno
# 6   NaN     20
# 8   NaN     20
# 13  NaN     20

# %%
df10 = df.drop(['comm2','sal+comm2'],axis=1)[df['deptno'] == 10]
df10
# Out:
#     empno   ename        job     mgr    hiredate   sal  comm  deptno
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09  2450   NaN      10
# 8    7839    KING  PRESIDENT     NaN  1981-11-17  5000   NaN      10
# 13   7934  MILLER      CLERK  7782.0  1982-01-23  1300   NaN      10

# %%
list_data = [7934,'MIL99','CLERK',7782.0,'1982-01-23',1300,0,10]
index_list = ['empno', 'ename', 'job', 'mgr', 'hiredate', 'sal', 'comm', 'deptno']

# %%
# 시리즈 어펜드 사용

# %%
list_data = [7934,'MIL99','CLERK',7782.0,'1982-01-23',1300,0,10]
data_list = ['empno', 'ename', 'job', 'mgr', 'hiredate', 'sal', 'comm', 'deptno']

list_sr=pd.Series(list_data, index = df10.columns)
df10 = df10.append(list_sr, ignore_index=True)
df10
# Out:
#    empno   ename        job     mgr    hiredate   sal  comm  deptno
# 0   7782   CLARK    MANAGER  7839.0  1981-06-09  2450   NaN      10
# 1   7839    KING  PRESIDENT     NaN  1981-11-17  5000   NaN      10
# 2   7934  MILLER      CLERK  7782.0  1982-01-23  1300   NaN      10
# 3   7934   MIL99      CLERK  7782.0  1982-01-23  1300   0.0      10

# %%
import numpy as np
a = np.array(list_data)
print(a, a.shape)
a.reshape(1,8)
print(a)
# Out:
# ['7934' 'MIL99' 'CLERK' '7782.0' '1982-01-23' '1300' '0' '10'] (8,)
# ['7934' 'MIL99' 'CLERK' '7782.0' '1982-01-23' '1300' '0' '10']

# %%
dff = pd.DataFrame(data = list_data)
dff.index = index_list
dff.info()
dff.head()
dt= dff.transpose()    # reshape는 넘피 어레이에서만 가능
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, empno to deptno
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       8 non-null      object
# dtypes: object(1)
# memory usage: 128.0+ bytes

# %%
dff1 = pd.DataFrame(data = [list_data])
dff1.columns = df10.columns.tolist()
dff1
# Out:
#    empno  ename    job     mgr    hiredate   sal  comm  deptno
# 0   7934  MIL99  CLERK  7782.0  1982-01-23  1300     0      10

# %%
nn= pd.concat([dt,df10],axis=0,ignore_index=True)   # 너무 복잡하다....
nn
# Out:
#   empno   ename        job     mgr    hiredate   sal comm deptno
# 0  7934   MIL99      CLERK  7782.0  1982-01-23  1300    0     10
# 1  7782   CLARK    MANAGER  7839.0  1981-06-09  2450  NaN     10
# 2  7839    KING  PRESIDENT     NaN  1981-11-17  5000  NaN     10
# 3  7934  MILLER      CLERK  7782.0  1982-01-23  1300  NaN     10

# %%
# data_list = [] 세로 프레임으로 만들어진다  pd로 갈때.
# 따라서 dat_list = [ []  ]  가로프레임 , 리스트 안에 리스트로 만들어야 한다.

# %%
df10 = df.drop(['comm2','sal+comm2'],axis=1)[df['deptno'] == 10]
list_data = [7934,'MIL99','CLERK',7782.0,'1982-01-23',1300,0,10]

# %%
listser = pd.Series(data=list_data)
listser_t = listser.transpose() #전치가 안된다..
print(listser_t.shape,listser_t.type)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7520/3458617991.py in <module>
#       1 listser = pd.Series(data=list_data)
#       2 listser_t = listser.transpose() #전치가 안된다..
# ----> 3 print(listser_t.shape,listser_t.type)
#
# C:\AI\pythonProject\venv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'type'

# %%
nnn = pd.concat([df10,listser],axis=1)
nnn    # 시리즈에서 전치해서 우리가 원하는 모양으로 데이터 프레임으로 붙이는건 안된다
# Out:
#      empno   ename        job     mgr    hiredate     sal  comm  deptno  \
# 0      NaN     NaN        NaN     NaN         NaN     NaN   NaN     NaN
# 1      NaN     NaN        NaN     NaN         NaN     NaN   NaN     NaN
# 2      NaN     NaN        NaN     NaN         NaN     NaN   NaN     NaN
# 3      NaN     NaN        NaN     NaN         NaN     NaN   NaN     NaN
# 4      NaN     NaN        NaN     NaN         NaN     NaN   NaN     NaN
# 5      NaN     NaN        NaN     NaN         NaN     NaN   NaN     NaN
# 6   7782.0   CLARK    MANAGER  7839.0  1981-06-09  2450.0   NaN    10.0
# 7      NaN     NaN        NaN     NaN         NaN     NaN   NaN     NaN
# 8   7839.0    KING  PRESIDENT     NaN  1981-11-17  5000.0   NaN    10.0
# 13  7934.0  MILLER      CLERK  7782.0  1982-01-23  1300.0   NaN    10.0
#
#              0
# 0         7934
# 1        MIL99
# 2        CLERK
# 3       7782.0
# 4   1982-01-23
# 5         1300
# 6            0
# 7           10
# 8          NaN
# ...

# %% [markdown]
# ### MERGE() = (db : JOIN)

# %%
# how : {left,right,outer,inner}
# 키값이 동일하면 : on
# 왼쪽 오른쪽 프레임에 조인해야 할 때 키값 다르다 : left_on, right_on

# %%
# dfcp = df.drop(  ['new_col', 'ename_job', 'comm2', 'sal+comm2'] , axis=1)
# df10 = df[ ['empno', 'ename', 'job', 'mgr', 'hiredate', 'sal', 'comm', 'deptno']][ df['deptno'] == 10 ].copy()

# %%
dfcp_10 = pd.merge(dfcp,df10, how = "inner", on = "deptno")
dfcp_10
# Out:
#    empno_x ename_x      job_x   mgr_x  hiredate_x  sal_x  comm_x  deptno  \
# 0     7782   CLARK    MANAGER  7839.0  1981-06-09   2450     NaN      10
# 1     7782   CLARK    MANAGER  7839.0  1981-06-09   2450     NaN      10
# 2     7782   CLARK    MANAGER  7839.0  1981-06-09   2450     NaN      10
# 3     7839    KING  PRESIDENT     NaN  1981-11-17   5000     NaN      10
# 4     7839    KING  PRESIDENT     NaN  1981-11-17   5000     NaN      10
# 5     7839    KING  PRESIDENT     NaN  1981-11-17   5000     NaN      10
# 6     7934  MILLER      CLERK  7782.0  1982-01-23   1300     NaN      10
# 7     7934  MILLER      CLERK  7782.0  1982-01-23   1300     NaN      10
# 8     7934  MILLER      CLERK  7782.0  1982-01-23   1300     NaN      10
#
#    empno_y ename_y      job_y   mgr_y  hiredate_y  sal_y  comm_y
# 0     7782   CLARK    MANAGER  7839.0  1981-06-09   2450     NaN
# 1     7839    KING  PRESIDENT     NaN  1981-11-17   5000     NaN
# ...

# %%
dfcp_10 = pd.merge(dfcp,df10, how = "right", on = "mgr")
dfcp_10
# Out:
#    empno_x ename_x      job_x     mgr  hiredate_x  sal_x  comm_x  deptno_x  \
# 0     7566   JONES    MANAGER  7839.0  1981-04-02   2975     NaN        20
# 1     7698   BLAKE    MANAGER  7839.0  1981-05-01   2850     NaN        30
# 2     7782   CLARK    MANAGER  7839.0  1981-06-09   2450     NaN        10
# 3     7839    KING  PRESIDENT     NaN  1981-11-17   5000     NaN        10
# 4     7934  MILLER      CLERK  7782.0  1982-01-23   1300     NaN        10
#
#    empno_y ename_y      job_y  hiredate_y  sal_y  comm_y  deptno_y
# 0     7782   CLARK    MANAGER  1981-06-09   2450     NaN        10
# 1     7782   CLARK    MANAGER  1981-06-09   2450     NaN        10
# 2     7782   CLARK    MANAGER  1981-06-09   2450     NaN        10
# 3     7839    KING  PRESIDENT  1981-11-17   5000     NaN        10
# 4     7934  MILLER      CLERK  1982-01-23   1300     NaN        10

# %%
deptdf1=[[10,'ACCOUNTING','NEW YORK'],
[20,'RESEARCH','DALLAS'],
[30,'SALES','CHICAGO'],
[40,'OPERATIONS','BOSTON']]

col_list=['deptno','dname','loc']

# %%
deptdf = pd.DataFrame(deptdf1)
deptdf.columns= col_list
deptdf
# Out:
#    deptno       dname       loc
# 0      10  ACCOUNTING  NEW YORK
# 1      20    RESEARCH    DALLAS
# 2      30       SALES   CHICAGO
# 3      40  OPERATIONS    BOSTON

# %%
dddd= pd.merge(dfcp,deptdf, how = "inner", on = "deptno")
dddd
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno  \
# 0    7369   SMITH      CLERK  7902.0  1980-12-17   800     NaN      20
# 1    7566   JONES    MANAGER  7839.0  1981-04-02  2975     NaN      20
# 2    7788   SCOTT    ANALYST  7566.0  1987-07-13  3000     NaN      20
# 3    7876   ADAMS      CLERK  7788.0  1987-07-13  1100     NaN      20
# 4    7902    FORD    ANALYST  7566.0  1981-12-03  3000     NaN      20
# 5    7499   ALLEN   SALESMAN  7698.0  1981-02-20  1600   300.0      30
# 6    7521    WARD   SALESMAN  7698.0  1981-02-22  1250   500.0      30
# 7    7654  MARTIN   SALESMAN  7698.0  1981-09-28  1250  1400.0      30
# 8    7698   BLAKE    MANAGER  7839.0  1981-05-01  2850     NaN      30
# 9    7844  TURNER   SALESMAN  7698.0  1981-09-08  1500     0.0      30
# 10   7900   JAMES      CLERK  7698.0  1981-12-03   950     NaN      30
# 11   7782   CLARK    MANAGER  7839.0  1981-06-09  2450     NaN      10
# ...

# %%
dddd= pd.merge(dfcp,deptdf, how = "right", on = "deptno")
dddd
# Out:
#      empno   ename        job     mgr    hiredate     sal    comm  deptno  \
# 0   7782.0   CLARK    MANAGER  7839.0  1981-06-09  2450.0     NaN      10
# 1   7839.0    KING  PRESIDENT     NaN  1981-11-17  5000.0     NaN      10
# 2   7934.0  MILLER      CLERK  7782.0  1982-01-23  1300.0     NaN      10
# 3   7369.0   SMITH      CLERK  7902.0  1980-12-17   800.0     NaN      20
# 4   7566.0   JONES    MANAGER  7839.0  1981-04-02  2975.0     NaN      20
# 5   7788.0   SCOTT    ANALYST  7566.0  1987-07-13  3000.0     NaN      20
# 6   7876.0   ADAMS      CLERK  7788.0  1987-07-13  1100.0     NaN      20
# 7   7902.0    FORD    ANALYST  7566.0  1981-12-03  3000.0     NaN      20
# 8   7499.0   ALLEN   SALESMAN  7698.0  1981-02-20  1600.0   300.0      30
# 9   7521.0    WARD   SALESMAN  7698.0  1981-02-22  1250.0   500.0      30
# 10  7654.0  MARTIN   SALESMAN  7698.0  1981-09-28  1250.0  1400.0      30
# 11  7698.0   BLAKE    MANAGER  7839.0  1981-05-01  2850.0     NaN      30
# ...

# %%
# left_on,right_on

# %%
dfcp.columns
# Out:
# Index(['empno', 'ename', 'job', 'mgr', 'hiredate', 'sal', 'comm', 'deptno'], dtype='object')

# %%
emp = df.drop(['comm2','sal+comm2'],axis=1)
emp = emp.rename(columns={"deptno":"DNO"})

# %%
emp.columns
# Out:
# Index(['empno', 'ename', 'job', 'mgr', 'hiredate', 'sal', 'comm', 'DNO'], dtype='object')

# %%
deptdf.columns  #두개가 컬럼이름이 다른데 조인할경우
# Out:
# Index(['deptno', 'dname', 'loc'], dtype='object')

# %%
emp_dept = pd.merge(emp,deptdf,how = "inner", left_on = "DNO" , right_on = "deptno")
emp_dept      #조인할 컬럼간의 이름이 다를경우 요렇게 사용하면 됩니다
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  DNO  deptno  \
# 0    7369   SMITH      CLERK  7902.0  1980-12-17   800     NaN   20      20
# 1    7566   JONES    MANAGER  7839.0  1981-04-02  2975     NaN   20      20
# 2    7788   SCOTT    ANALYST  7566.0  1987-07-13  3000     NaN   20      20
# 3    7876   ADAMS      CLERK  7788.0  1987-07-13  1100     NaN   20      20
# 4    7902    FORD    ANALYST  7566.0  1981-12-03  3000     NaN   20      20
# 5    7499   ALLEN   SALESMAN  7698.0  1981-02-20  1600   300.0   30      30
# 6    7521    WARD   SALESMAN  7698.0  1981-02-22  1250   500.0   30      30
# 7    7654  MARTIN   SALESMAN  7698.0  1981-09-28  1250  1400.0   30      30
# 8    7698   BLAKE    MANAGER  7839.0  1981-05-01  2850     NaN   30      30
# 9    7844  TURNER   SALESMAN  7698.0  1981-09-08  1500     0.0   30      30
# 10   7900   JAMES      CLERK  7698.0  1981-12-03   950     NaN   30      30
# ...
