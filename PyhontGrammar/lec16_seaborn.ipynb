# %% [markdown]
# # chOO.시각화

# %% [markdown]
# ## seaborn
# * ref : https://seaborn.pydata.org/examples/index.html
# * ref : https://scikit-learn.org/stable/datasets/toy_dataset.html
# * 시각화 기능(Matplotlib) + 통계(Statsmodels) 기반으로 다양한 색상과 통계용 차트 등의 기능을 추가한 패키지

# %%
# ! pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
sns.set()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8260/2220917571.py in <module>
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 from sklearn.datasets import load_boston
#       6 sns.set()
#
# c:\ai\pythonproject\venv\lib\site-packages\sklearn\datasets\__init__.py in <module>
#       5 """
#       6 from ._base import load_breast_cancer
# ----> 7 from ._base import load_boston
#       8 from ._base import load_diabetes
#       9 from ._base import load_digits
#
# ImportError: cannot import name 'load_boston' from 'sklearn.datasets._base' (c:\ai\pythonproject\venv\lib\site-packages\sklearn\datasets\_base.py)

# %%
plt.rcParams['font.family'] = 'NanumGothic'

# %% [markdown]
# <table style="border-collapse: collapse; border: none; mso-border-alt: solid #A3A3A3 1.0pt; mso-yfti-tbllook: 1184; mso-padding-alt: 0cm 0cm 0cm 0cm;" border="1" cellspacing="0" cellpadding="0" data-ke-align="alignLeft">
# <tbody>
# <tr>
# <td style="width: 53.0pt; border: solid #A3A3A3 1.0pt; background: #DEEBF6; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="71"><span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">속성</span></span></td>
# <td style="width: 241.8pt; border: solid #A3A3A3 1.0pt; border-left: none; mso-border-left-alt: solid #A3A3A3 1.0pt; background: #DEEBF6; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="322"><span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">설명</span></span></td>
# </tr>
# <tr>
# <td style="width: 53.0pt; border: solid #A3A3A3 1.0pt; border-top: none; mso-border-top-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="71"><span><span style="font-size: 10.0pt; font-family: Consolas;">CRIM</span></span></td>
# <td style="width: 241.8pt; border-top: none; border-left: none; border-bottom: solid #A3A3A3 1.0pt; border-right: solid #A3A3A3 1.0pt; mso-border-top-alt: solid #A3A3A3 1.0pt; mso-border-left-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="322"><span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">범죄율</span></span></td>
# </tr>
# <tr>
# <td style="width: 53.0pt; border: solid #A3A3A3 1.0pt; border-top: none; mso-border-top-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="71"><span><span style="font-size: 10.0pt; font-family: Consolas;">INDUS</span></span></td>
# <td style="width: 241.8pt; border-top: none; border-left: none; border-bottom: solid #A3A3A3 1.0pt; border-right: solid #A3A3A3 1.0pt; mso-border-top-alt: solid #A3A3A3 1.0pt; mso-border-left-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="322"><span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">비소매상업지역</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">면적</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">비율</span></span></td>
# </tr>
# <tr>
# <td style="width: 53.0pt; border: solid #A3A3A3 1.0pt; border-top: none; mso-border-top-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="71"><span><span style="font-size: 10.0pt; font-family: Consolas;">NOX</span></span></td>
# <td style="width: 241.8pt; border-top: none; border-left: none; border-bottom: solid #A3A3A3 1.0pt; border-right: solid #A3A3A3 1.0pt; mso-border-top-alt: solid #A3A3A3 1.0pt; mso-border-left-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="322"><span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">일산화질소</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">농도</span></span></td>
# </tr>
# <tr>
# <td style="width: 53.0pt; border: solid #A3A3A3 1.0pt; border-top: none; mso-border-top-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="71"><span><span style="font-size: 10.0pt; font-family: Consolas;">RM</span></span></td>
# <td style="width: 241.8pt; border-top: none; border-left: none; border-bottom: solid #A3A3A3 1.0pt; border-right: solid #A3A3A3 1.0pt; mso-border-top-alt: solid #A3A3A3 1.0pt; mso-border-left-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="322"><span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">주택당</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">방</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">수</span></span></td>
# </tr>
# <tr>
# <td style="width: 53.0pt; border: solid #A3A3A3 1.0pt; border-top: none; mso-border-top-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="71"><span><span style="font-size: 10.0pt; font-family: Consolas;">LSTAT</span></span></td>
# <td style="width: 241.8pt; border-top: none; border-left: none; border-bottom: solid #A3A3A3 1.0pt; border-right: solid #A3A3A3 1.0pt; mso-border-top-alt: solid #A3A3A3 1.0pt; mso-border-left-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="322"><span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">인구</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">중</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">하위</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">계층</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">비율</span></span></td>
# </tr>
# <tr>
# <td style="width: 53.0pt; border: solid #A3A3A3 1.0pt; border-top: none; mso-border-top-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="71"><span><span style="font-size: 10.0pt; font-family: Consolas;">B</span></span></td>
# <td style="width: 241.8pt; border-top: none; border-left: none; border-bottom: solid #A3A3A3 1.0pt; border-right: solid #A3A3A3 1.0pt; mso-border-top-alt: solid #A3A3A3 1.0pt; mso-border-left-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="322"><span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">인구</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">중</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">흑인</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">비율</span></span></td>
# </tr>
# <tr>
# <td style="width: 53.0pt; border: solid #A3A3A3 1.0pt; border-top: none; mso-border-top-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="71"><span><span style="font-size: 10.0pt; font-family: Consolas;">PTRATIO</span></span></td>
# <td style="width: 241.8pt; border-top: none; border-left: none; border-bottom: solid #A3A3A3 1.0pt; border-right: solid #A3A3A3 1.0pt; mso-border-top-alt: solid #A3A3A3 1.0pt; mso-border-left-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="322"><span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">학생</span><span style="font-size: 10.0pt; font-family: Consolas;">/</span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">교사</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">비율</span></span></td>
# </tr>
# <tr>
# <td style="width: 53.0pt; border: solid #A3A3A3 1.0pt; border-top: none; mso-border-top-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="71"><span><span style="font-size: 10.0pt; font-family: Consolas;">ZN</span></span></td>
# <td style="width: 241.8pt; border-top: none; border-left: none; border-bottom: solid #A3A3A3 1.0pt; border-right: solid #A3A3A3 1.0pt; mso-border-top-alt: solid #A3A3A3 1.0pt; mso-border-left-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="322"><span><span style="font-size: 10.0pt; font-family: Consolas;">25,000 </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">평방피트를</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">초과</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">거주지역</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">비율</span></span></td>
# </tr>
# <tr>
# <td style="width: 53.0pt; border: solid #A3A3A3 1.0pt; border-top: none; mso-border-top-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="71"><span><span style="font-size: 10.0pt; font-family: Consolas;">CHAS</span></span></td>
# <td style="width: 241.8pt; border-top: none; border-left: none; border-bottom: solid #A3A3A3 1.0pt; border-right: solid #A3A3A3 1.0pt; mso-border-top-alt: solid #A3A3A3 1.0pt; mso-border-left-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="322"><span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">찰스강의</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">경계에</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">위치</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">유무</span></span><br />
# <table style="border-collapse: collapse; border: none; mso-border-alt: solid #A3A3A3 1.0pt; mso-yfti-tbllook: 1184; mso-padding-alt: 0cm 0cm 0cm 0cm;" border="1" cellspacing="0" cellpadding="0" data-ke-align="alignLeft">
# <tbody>
# <tr>
# <td style="width: 48.0pt; border: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="63"><span><span style="font-size: 10.0pt; font-family: Consolas;">1</span></span></td>
# <td style="width: 190.1pt; border: solid #A3A3A3 1.0pt; border-left: none; mso-border-left-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="248"><span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">찰스강의</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">경계에</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">위치한</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">경우</span></span></td>
# </tr>
# <tr>
# <td style="width: 48.0pt; border: solid #A3A3A3 1.0pt; border-top: none; mso-border-top-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="63"><span><span style="font-size: 10.0pt; font-family: Consolas;">0</span></span></td>
# <td style="width: 190.1pt; border-top: none; border-left: none; border-bottom: solid #A3A3A3 1.0pt; border-right: solid #A3A3A3 1.0pt; mso-border-top-alt: solid #A3A3A3 1.0pt; mso-border-left-alt: solid #A3A3A3 1.0pt; padding: 4.0pt 4.0pt 4.0pt 4.0pt;" valign="top" width="248"><span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">찰스강의</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">경계에</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">위치하지</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">않은</span><span style="font-size: 10.0pt; font-family: Consolas;"> </span><span style="font-size: 10.0pt; font-family: '맑은 고딕';">경우</span></span></td>
# </tr>
# </tbody>
# </table>

# %%
# %matplotlib inline  
#cell  magic

# %%
# user = pd.read_csv("./lec13_pandas_quiz/dataset/user.csv")
# score = pd.read_csv("./lec13_pandas_quiz/dataset/score.csv")
# df = pd.merge(user, score, how='inner' , on='sno')
# df.head()

df = sns.load_dataset("penguins")
df.head()

# %%
pivot = df.pivot_table(index='sex', columns='body_mass_g', values='bill_length_mm')
pivot
# Out:
# body_mass_g  2700.0  2850.0  2900.0  2925.0  3000.0  3050.0  3075.0  3100.0  \
# sex
# Female         46.9   36.45   37.35    37.9   37.15   35.55    37.7    36.0
# Male            NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# body_mass_g  3150.0  3175.0  3200.0  3250.0  3275.0  3300.0  3325.0  3350.0  \
# sex
# Female       36.575   36.85   39.36  42.775    38.8    40.0   39.35    38.7
# Male            NaN     NaN     NaN  51.500     NaN    50.3   41.10     NaN
#
# body_mass_g     3400.0  3425.0     3450.0  3475.0  3500.0  3525.0  3550.0  \
# sex
# Female       41.871429    38.1  38.428571    36.6   41.06    45.5  38.540
# Male         48.500000    41.1  52.200000    40.6   40.40     NaN  43.125
#
# body_mass_g  3575.0  3600.0  3625.0     3650.0  3675.0   3700.0  3725.0  \
# sex
# Female         45.9   39.62    38.9  46.233333   50.35  42.3125    35.0
# Male            NaN   43.70     NaN  43.200000     NaN  46.3500    46.7
#
# ...

# %% [markdown]
# ## Regression

# %%
sns.regplot(x="total_bill", y="tip", data=tips)
sns.relplot(data=df, x="total_bill", y="tip" )  #column간 선형관계 확인
sns.lmplot(data=df,  x="total_bill", y="tip")   # relplot + 선

# %% [markdown]
# ## Categorical

# %%
sns.catplot(data=df, x="obj컬럼", y="int컬럼", kind="bar")  
sns.catplot(data=df, x="obj컬럼", y="int컬럼", kind="count")    sns.countplot(data=df, x="species")
sns.catplot(data=df, x="obj컬럼", y="int컬럼", kind="box")      sns.boxplot(data=df, x="species", y="flipper_length_mm")
sns.catplot(data=df, x="obj컬럼", y="int컬럼", kind="violin")   sns.violinplot(x=df.species, y=df.flipper_length_mm)          # 분포도
                                                               sns.histplot(data=df, x="flipper_length_mm", hue="species")   # ,col="species"
                                                               sns.kdeplot (data=df, x="flipper_length_mm", hue="species")   #hist보다 부드려운 곡선
                                                               sns.displot (data=df, x="flipper_length_mm", hue="species")   #matplotlib.hist + kdeplot
                                                               sns.relplot (data=df, x="bill_length_mm", y="bill_depth_mm")
sns.catplot(data=df, x="species", y="bill_length_mm")          sns.scatterplot(data=df, x="flipper_length_mm", y="bill_length_mm")
                                                                
                                                               sns.heatmap(df.corr(), annot=True)
                                                               sns.lineplot(data=df, x="flipper_length_mm", y="bill_length_mm")     
                                                               sns.pairplot(df)                                                   # hist + scatter
                                                               sns.jointplot(data=df, x="flipper_length_mm", y="bill_length_mm")  # hist + scatter
f, axs = plt.subplots(1, 2, figsize=(9, 4))
sns.scatterplot(data=df, x="flipper_length_mm", y="bill_length_mm", ax=axs[0])
sns.scatterplot(data=df, x="flipper_length_mm", y="bill_length_mm", ax=axs[1])

# %% [markdown]
# ### Bar chart

# %%
sns.catplot(data=df, x="species", y="flipper_length_mm", kind="bar")

# %%
sns.catplot(data=df, x="species", kind="count")

# %%
sns.countplot(data=df, x="species")

# %% [markdown]
# ### boxplot

# %%
sns.catplot(data=df, x="species", y="flipper_length_mm", kind="box")

# %%
sns.catplot(data=df, x="species", y="flipper_length_mm", hue="sex", kind="box")

# %%
sns.violinplot(x=df.species, y=df.flipper_length_mm)

# %%
sns.catplot(data=df, x="species", y="flipper_length_mm", kind="violin")

# %%
sns.catplot(data=df, x="species", y="flipper_length_mm", hue="sex", kind="violin")

# %% [markdown]
# ### histogram
# *  도수분포표 : x축(계급), y축(도수,갯수)

# %%
sns.histplot(data=df, x="flipper_length_mm", hue="species")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.kdeplot(data=df, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sns.displot(data=df, x="flipper_length_mm", hue="species", col="species")

# %%
g = sns.relplot(data=df, x="bill_length_mm", y="bill_depth_mm")
g.ax.axline(xy1=(0, 5), slope=.2, color="b", dashes=(5, 2))

# %% [markdown]
# ### heatmap

# %%
arr = np.random.standard_normal((30, 40))

plt.matshow(arr, cmap='bwr')  #BuGn
plt.colorbar()
plt.show()

# %% [markdown]
# ### scatter

# %%
sns.scatterplot(data=df, x="flipper_length_mm", y="bill_length_mm", hue="sex")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
#sns.catplot(x="species", y="flipper_length_mm", data=df)
sns.catplot(data=df, x="species", y="bill_length_mm", hue="sex", order=['Adelie', 'Gentoo', 'Chinstrap'],)

# %% [markdown]
# ## 여러 개의 그래프 그리기

# %% [markdown]
# ### subplot()

# %% [markdown]
# <img src="https://wikidocs.net/images/page/141537/subplot_03.png" width=700>

# %%
fig, axs = plt.subplots(2, 3, figsize=(9, 3))

# %%
g = sns.FacetGrid(df, col="sex")

# %%
g = sns.FacetGrid(df, col="species", height=3.5, aspect=.75)
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# #### (방법1) subplot 1개에 2개 차트 그려보기
# * plt.subplots(1, 4, figsize=(16, 3))

# %%
f, axs = plt.subplots(1, 2, figsize=(9, 4))
sns.scatterplot(data=df, x="flipper_length_mm", y="bill_length_mm", hue="species", ax=axs[0])
sns.histplot(data=df, x="species", hue="species", shrink=.8, alpha=.8, legend=False, ax=axs[1])
f.tight_layout()
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# #### (방법2) 2개 차트 결합(Combining)

# %%
sns.jointplot(data=df, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue="species")

# %% [markdown]
# #### (방법2) subplot 4개에 차트 그려보기
# * 이전방법 : plt.subplots(1, 4, figsize=(16, 3))
# * 편한방법 : myfig, myax = plt.subplots(1, 4, figsize=(16, 3))

# %%
myall, my = plt.subplots(1, 4, figsize=(16, 3))    # 1행 4열 그래프를 16:3비율 크기로 그리기

my[0].bar(df['name'], df['cnt'])
my[1].scatter(df['name'], df['cnt'])
my[2].plot(df['name'], df['cnt'])
my[3].boxplot(df['cnt'])

my[0].grid()
myall.suptitle('subplot test')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\ai\pythonproject\venv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\ai\pythonproject\venv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\ai\pythonproject\venv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# #### (방법3) subplot 2개에 차트 그려보기
# * 첫번째 subplot :  라인차트(plot) 2개 그리기
# * 두번째 subplot :  라인차트(plot) 1개 그리기

# %%
# plt.subplot(2,1,1)
plt.subplot(211)
plt.plot(df['name'], df['cnt']+10  , color='black')
plt.plot(df['name'], df['cnt']     , color='blue'    , marker='o')

# plt.subplot(2,1,2)
plt.subplot(212)
plt.plot(df['name'], df['cnt']     , color='orange' , marker='o' , linestyle='--')
plt.show()

# %% [markdown]
# #### subplot 2개에 Pie 차트 그려보기

# %%
myfig, myax = plt.subplots(1, 2)
myax[0].pie(df['cnt'], labels=df['name'], autopct='%.2f')
myax[1].pie(df['cnt'], labels=df['name'], explode=[0.1, 0.2, 0.05, 0.05], autopct='%.1f %%', shadow=True, startangle=90)
plt.show()

# %% [markdown]
# ### twinx() : y축이 좌,우 2개

# %%
# Create some mock data
xdata  = [1,2,3,4]
ydata1 = [10,15,5,20]
ydata2 = [252,200,300,400]

myfig, myax = plt.subplots()
# -------------------------------------공통
myax.set_xlabel('X')
myax.grid()
# -------------------------------------왼쪽
myax.set_ylabel('Y-left' , color='red')
myax.plot(xdata, ydata1  , color='red')
# -------------------------------------오른쪽
myax_cp = myax.twinx()  #-------------- 왼쪽 y축  오른쪽으로 복제
myax_cp.set_ylabel('Y-right', color='blue') 
myax_cp.plot(xdata, ydata2  , color='blue')

plt.show()

# %% [markdown]
# ## 차트 이미지로 저장하기

# %%
plt.plot(df['name'], df['cnt']     , color='orange' , marker='o' , linestyle='--')
plt.savefig('./lec15_chart_save.jpg')

# %% [markdown]
# ## 저장한 차트이미지 불러오기

# %%
# ! pip install pillow
# ! pip install matplotlib

# %% [markdown]
# ### (방법1) jupyter인 경우 마크다운에 &lt;HTML&gt;  사용
# * &lt;img src='./lec15_chart_save.jpg' width='300' height='150'&gt;

# %% [markdown]
# <img src='./lec15_chart_save.jpg' width='300' height='150'>

# %% [markdown]
# ### (방법2) matplotlib 패키기 imshow() 사용

# %%
from matplotlib.pyplot import imshow
from PIL import Image

myimg = Image.open('./lec15_chart_save.jpg', 'r')
# plt.imshow(myimg)
# imshow(myimg)
# display(myimg)
myimg

# %% [markdown]
# ### (방법3) pillow 패키지 display() 이용하기

# %%
from PIL import Image
myimg = Image.open('./lec15_chart_save.jpg')     #----------- 열기
print(myimg.size)                                #----------- 크기   
myimg.thumbnail(  (300, 75)  )                   #----------- 크기 변경
myimg.save('./lec15_chart_save222.jpg')          #----------- 저장

# %%
myimg = Image.open('./lec15_chart_save222.jpg')  #----------- 보기
display(myimg)
# myimg.show()  -------------------- jupyter가 멈춤.. 실행하지말것
